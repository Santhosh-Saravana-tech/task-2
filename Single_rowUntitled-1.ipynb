-- %% [markdown]
-- Single row function
-- List
-- 😩
-- - First item
-- - Second item
-- - Third itemUPPER
--
-- ```sql
-- SELECT * FROM employees;
-- ```

-- %%
select * from employees;
-- Out:
-- (150 rows affected)
--
-- employee_id | first_name  | last_name  | email                         | hire_date  | job_title                | salary
-- ------------+-------------+------------+-------------------------------+------------+--------------------------+----------
-- 1           | John        | Doe        | john.doe@example.com          | 2023-01-15 | Software Engineer        | 75000.00
-- 2           | Jane        | Smith      | jane.smith@example.com        | 2023-01-20 | Project Manager          | 85000.00
-- 3           | Michael     | Johnson    | michael.johnson@example.com   | 2023-02-01 | Data Analyst             | 68000.00
-- 4           | Emily       | Williams   | emily.williams@example.com    | 2023-02-10 | HR Manager               | 72000.00
-- 5           | David       | Brown      | david.brown@example.com       | 2023-02-15 | QA Engineer              | 70000.00
-- ...
